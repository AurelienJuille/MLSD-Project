# %% [markdown]
# Install Dependencies

# %%
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/javi/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: matplotlib in /home/javi/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: ipywidgets in /home/javi/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (8.1.5)
# Requirement already satisfied: scikit-learn in /home/javi/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/javi/.local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/javi/.local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/javi/.local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/javi/.local/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/javi/.local/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/javi/.local/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib->-r requirements.txt (line 2)) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/javi/.local/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/javi/.local/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: traitlets>=4.3.1 in /home/javi/.local/lib/python3.10/site-packages (from ipywidgets->-r requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/javi/.local/lib/python3.10/site-packages (from ipywidgets->-r requirements.txt (line 3)) (8.28.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/javi/.local/lib/python3.10/site-packages (from ipywidgets->-r requirements.txt (line 3)) (3.0.13)
# Requirement already satisfied: comm>=0.1.3 in /home/javi/.local/lib/python3.10/site-packages (from ipywidgets->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/javi/.local/lib/python3.10/site-packages (from ipywidgets->-r requirements.txt (line 3)) (4.0.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/javi/.local/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/javi/.local/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/javi/.local/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: stack-data in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: decorator in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: matplotlib-inline in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: jedi>=0.16 in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: typing-extensions>=4.6 in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/javi/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (3.0.48)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/javi/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: wcwidth in /home/javi/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: pure-eval in /home/javi/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/javi/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/javi/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 3)) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, auc, classification_report, f1_score, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Load Dataset

# %%
# Load the processed dataset
df = pd.read_csv("data/processed_dataset.csv", index_col=0)
print("Dataset loaded successfully from 'data/processed_dataset.csv'")

df.head()
# Out:
# Dataset loaded successfully from 'data/processed_dataset.csv'
#                   blueTeamControlWardsPlaced  blueTeamWardsPlaced  \
# matchId
# EUW1_6882489515'                           2                   23
# EUW1_6882416210'                           2                   46
# EUW1_6881092720'                           2                   19
# EUW1_6879405717'                           3                   28
# EUW1_6879389461'                           3                   30
#
#                   blueTeamTotalKills  blueTeamDragonKills  \
# matchId
# EUW1_6882489515'                   4                    2
# EUW1_6882416210'                  12                    1
# EUW1_6881092720'                  13                    0
# EUW1_6879405717'                   8                    0
# EUW1_6879389461'                  11                    1
#
#                   blueTeamHeraldKills  blueTeamTowersDestroyed  \
# matchId
# EUW1_6882489515'                    0                        0
# EUW1_6882416210'                    0                        1
# EUW1_6881092720'                    0                        0
# EUW1_6879405717'                    1                        1
# EUW1_6879389461'                    1                        1
#
#                   blueTeamInhibitorsDestroyed  blueTeamTurretPlatesDestroyed  \
# matchId
# EUW1_6882489515'                            0                              7
# EUW1_6882416210'                            0                             10
# EUW1_6881092720'                            0                             11
# EUW1_6879405717'                            0                              9
# EUW1_6879389461'                            0                              7
#
#                   blueTeamFirstBlood  blueTeamMinionsKilled  ...  \
# matchId                                                      ...
# EUW1_6882489515'                   0                    388  ...
# EUW1_6882416210'                   0                    348  ...
# EUW1_6881092720'                   0                    331  ...
# EUW1_6879405717'                   1                    355  ...
# EUW1_6879389461'                   0                    370  ...
#
#                   diffJungleMinions  diffTotalGold  diffTotalKills  diffXp  \
# matchId
# EUW1_6882489515'                 12          -5714             -12   -2815
# EUW1_6882416210'                 22          -1118              -5     210
# EUW1_6881092720'                 12          -2384              -5      37
# EUW1_6879405717'                 -3           2176              -2    -603
# EUW1_6879389461'                  4           1720               4    1591
#
#                   diffTotalDamageToChamps  diffDragonKills  diffHeraldKills  \
# matchId
# EUW1_6882489515'                    -5397                2                0
# EUW1_6882416210'                     -768                1                0
# EUW1_6881092720'                    -4945               -1                0
# EUW1_6879405717'                     3109               -1                1
# EUW1_6879389461'                     7431                0                1
#
#                   diffTowersDestroyed  diffInhibitorsDestroyed  \
# matchId
# EUW1_6882489515'                   -2                        0
# EUW1_6882416210'                    0                        0
# EUW1_6881092720'                   -2                        0
# EUW1_6879405717'                    1                        0
# EUW1_6879389461'                    0                        0
#
#                   diffTurretPlatesDestroyed
# matchId
# EUW1_6882489515'                          6
# EUW1_6882416210'                          6
# EUW1_6881092720'                          8
# EUW1_6879405717'                          4
# EUW1_6879389461'                          2
#
# [5 rows x 39 columns]

# %% [markdown]
# Train-test Split

# %%
X = df.drop(columns=["blueWin"])
y = df["blueWin"]

print("X shape:", X.shape)
print("y shape:", y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# X shape: (24218, 38)
# y shape: (24218,)

# %% [markdown]
# Scaling

# %%
scaler = preprocessing.StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Feature Selection

# %%
def find_bestKfeatures(model):
  print("Performing feature selection...")
  # Select best k features
  k = -1
  max_score = 0
  for i in range(1, 16, 2):
    selector = SelectKBest(k=i)
    pipeline = Pipeline([('selector', selector), ('model', model)])
    pipeline.fit(X_train, y_train)
    score = pipeline.score(X_test, y_test)
    print("K: {}, score: {}".format(i, score))
    if score > max_score:
      k = i
      max_score = score
      selected_features_indices = selector.get_support(indices=True)
  print("Best K number: {}, score: {}".format(k, max_score))
  print("Selected features: ", list(X.columns[selected_features_indices]))
  print()
  # return feature index list
  return list(selected_features_indices)

def apply_feature_selection(X, selected_features_indices):
  return X[:, selected_features_indices]

# %% [markdown]
# Hyper-Parameter Tuning

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=0)

def train_model_with_random_search(model, param_grid, X_train, y_train):
    print("Starting training...")

    # Initialize RandomizedSearchCV
    random_search = RandomizedSearchCV(model, param_distributions=param_grid, n_iter=10, 
                                       scoring='accuracy', n_jobs=-1, cv=cv)

    # Fit RandomizedSearchCV
    random_search.fit(X_train, y_train)

    print("Training completed")
    print()

    # Get best estimator
    best_model = random_search.best_estimator_
    # Get best training score
    best_score = random_search.best_score_
    print('Best Training Score: ', best_score)
    # Get best param
    best_param = random_search.best_params_
    print('Best Parameters: ', best_param)
    print()

    # Return model
    return best_model, best_param

# %% [markdown]
# Model Evaluation

# %%
def evaluate_model(model, X_test):
    print("Model Evaluation: ")

    # Predict on test set
    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]

    # Compute evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    roc_auc = roc_auc_score(y_test, y_pred_prob)

    print('Accuracy: ', accuracy)
    print('F1 Score: ', f1)
    print('AUC(ROC): ', roc_auc)
    print()
    print("Classification Report: ")
    print(classification_report(y_test, y_pred))

    # ROC AUC plot
    fper, tper, _ = roc_curve(y_test, y_pred_prob)

    fig, ax = plt.subplots(figsize=(5, 5))
    ax.plot(fper, tper, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver Operating Characteristic (ROC) Curve')
    ax.legend(loc="lower right")

    plt.show()

    return accuracy, f1, roc_auc

# %% [markdown]
# Random Forest Classifier

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'criterion': ['gini'],
    'max_depth': [None, 3, 4, 5, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

model = RandomForestClassifier()

# Perform feature selection
selected_features = find_bestKfeatures(model)
X_train_rd, X_test_rd = apply_feature_selection(X_train, selected_features), apply_feature_selection(X_test, selected_features)

# Train model with RandomizedSearchCV
trained_model, param_sample = train_model_with_random_search(model, param_grid, X_train_rd, y_train)

# Evaluate model
accuracy, f1, roc_auc = evaluate_model(trained_model, X_test_rd)
# Out:
# Performing feature selection...
# K: 1, score: 0.6934351775392238
# K: 3, score: 0.7113955408753097
# K: 5, score: 0.7372006606110653
# K: 7, score: 0.7400908340214699
# K: 9, score: 0.7433938893476466
# K: 11, score: 0.7448389760528489
# K: 13, score: 0.7450454170107349
# K: 15, score: 0.7479355904211396
# Best K number: 15, score: 0.7479355904211396
# Selected features:  ['blueTeamTotalKills', 'blueTeamTotalGold', 'blueTeamXp', 'redTeamTotalKills', 'redTeamTurretPlatesDestroyed', 'redTeamTotalGold', 'redTeamXp', 'diffMinionsKilled', 'diffTotalGold', 'diffTotalKills', 'diffXp', 'diffTotalDamageToChamps', 'diffDragonKills', 'diffTowersDestroyed', 'diffTurretPlatesDestroyed']
#
# Starting training...
# Training completed
#
# Best Training Score:  0.7598839442436758
# Best Parameters:  {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': None, 'criterion': 'gini', 'bootstrap': False}
#
# Model Evaluation:
# Accuracy:  0.7530966143682907
# F1 Score:  0.7530948460571827
# AUC(ROC):  0.8360694174667056
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      2463
#            1       0.75      0.75      0.75      2381
#
#     accuracy                           0.75      4844
#    macro avg       0.75      0.75      0.75      4844
# weighted avg       0.75      0.75      0.75      4844
